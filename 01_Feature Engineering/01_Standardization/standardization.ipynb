# %% [markdown]
# # **Learning Standardization**

# %%
from IPython.display import HTML
shell = get_ipython()

def adjust_font_size():
    display(HTML('''<style>
        body {
            font-size: 18px;
        }
    </style>'''))

if adjust_font_size not in shell.events.callbacks['pre_execute']:
    shell.events.register('pre_execute', adjust_font_size)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import zipfile

# Update the path to point to the actual zip file
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/ML Codes/Feature Engineering/datasets/archive .zip", 'r')
zip_ref.extractall("/content/dataset")
zip_ref.close()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
files = os.listdir("/content/dataset")
print("Extracted files:", files)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# Extracted files: ['Social_Network_Ads.csv']

# %%
df = pd.read_csv("/content/dataset/" + files[0])
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
df.head(5)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.shape
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# (400, 5)

# %% [markdown]
# ## **Removing Unnecessary Columns**

# %%
df = df.iloc[:, 2:]
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
df
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %% [markdown]
# ## **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
# Create feature columns
X = df.drop('Purchased', axis=1)
# Create target column
y = df['Purchased']

# Split the dataset into train and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
# Check the shape of the splits
print(X_train.shape)  # Train features
print(X_test.shape)   # Test features
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# (280, 2)
# (120, 2)

# %% [markdown]
# ## **StandardScaler**

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler to the training set
scaler.fit(X_train)

# Transform the training and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
X_train
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [280 rows x 2 columns]

# %%
#  Return Numpy array
X_test_scaled
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# array([[-0.77101313,  0.49720103],
#        [ 0.0133054 , -0.57280368],
#        [-0.28081405,  0.15017248],
#        [-0.77101313,  0.26584866],
#        [-0.28081405, -0.57280368],
#        [-1.06513258, -1.44037507],
#        [-0.67297331, -1.5849703 ],
#        [-0.18277423,  2.14558666],
#        [-1.94749093, -0.05226085],
#        [ 0.89566375, -0.775237  ],
#        [-0.77101313, -0.60172273],
#        [-0.96709276, -0.42820845],
#        [-0.08473441, -0.42820845],
#        [ 0.11134522,  0.20801057],
#        [-1.7514113 ,  0.46828198],
#        [-0.5749335 ,  1.36477242],
#        [-0.08473441,  0.20801057],
#        [-1.84945111,  0.43936294],
#        [ 1.67998229,  1.74072002],
#        [-0.28081405, -1.38253697],
# ...

# %% [markdown]
# **What this does:**
#
# * X_train_scaled and X_test_scaled are numpy arrays after using scaler.transform().
# * We wrap them in pd.DataFrame(...) and assign the original column names from X_train.columns and X_test.columns respectively, so the scaled data remains interpretable.

# %%
# Assuming X_train and X_test are DataFrames
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
X_train_scaled
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %% [markdown]
# ## **Checking Scaling**

# %%
# From Original Dataset
np.round(X_train.describe(),1)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
# Transformed Data
np.round(X_train_scaled.describe(),1)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %% [markdown]
# ## **Effect of Scaling**

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# Scatter plot before scaling
ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax1.set_xlabel("Age")
ax1.set_ylabel("EstimatedSalary")

# Scatter plot after scaling
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'], color='red')
ax2.set_title("After Scaling")
ax2.set_xlabel("Age")
ax2.set_ylabel("EstimatedSalary")

# Show plot
plt.tight_layout()
plt.show()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the figure and axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# KDE plots before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1, label='Age')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1, label='EstimatedSalary')
ax1.legend()

# KDE plots after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2, label='Age')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2, label='EstimatedSalary')
ax2.legend()

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %% [markdown]
# ## **Comparison of Distributions**

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Age Distribution Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)

# after scaling
ax2.set_title('Age Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
plt.show()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('Salary Distribution Standard Scaling')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %% [markdown]
# ## **Why scaling is important?**

# %%
from sklearn.linear_model import LogisticRegression
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
from sklearn.metrics import accuracy_score
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# Actual 0.875
# Scaled 0.8666666666666667

# %%
from sklearn.tree import DecisionTreeClassifier
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
dt.fit(X_train,y_train)
dt_scaled.fit(X_train_scaled,y_train)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled.predict(X_test_scaled)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# Actual 0.875
# Scaled 0.8583333333333333

# %%
df.describe()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# ## Outliers Effect

# %%
# Use the pandas top-level concat function
df = pd.concat([df, pd.DataFrame({'Age':[5,90,95],'EstimatedSalary':[1000,250000,350000],'Purchased':[0,1,1]})], ignore_index=True)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
df
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 398   36            33000          0
# 399   49            36000          1
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
#
# [403 rows x 3 columns]

# %%
plt.scatter(df['Age'], df['EstimatedSalary'])
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
# Create feature columns
X = df.drop('Purchased', axis=1)
# Create target column
y = df['Purchased']

# Split the dataset into train and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
# Check the shape of the splits
print(X_train.shape)  # Train features
print(X_test.shape)   # Test features
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# (282, 2)
# (121, 2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()
# Out:
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
# <style>
#         body {
#             font-size: 18px;
#         }
#     </style>
